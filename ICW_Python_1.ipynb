# %% [markdown]
# <a href="https://colab.research.google.com/github/tracydo99/bus4-110a/blob/main/ICW_Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2bob = "Hello World!"
print(2bob)
# Out:
#   File "/tmp/ipython-input-1309347802.py", line 1
#     2bob = "Hello World!"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# I get a "SyntaxError: invalid decimal literal". One of the rules of creating variables is that it cannot start with a number.

# %%
TestVar = False

# %% [markdown]
# In this code, **TestVar** is a type of *bool*.

# %%
quote = 'Ada Lovelace coded the first "computer,"' + " Carles Babbage's Analytic Engine."
print (quote)
# Out:
# Ada Lovelace coded the first "computer," Carles Babbage's Analytic Engine.

# %%
Num = 4
print("You have now completed: " + str(Num) + " exercises!")
# Out:
# You have now completed: 4 exercises!

# %%
guestlist = ["Yong-Mi","Jeff","Viet","Rui","Samantha"]
for guest in guestlist:
  print(guest + ", please join us for a BBQ next Saturday at 6pm.")
# Out:
# Yong-Mi, please join us for a BBQ next Saturday at 6pm.
# Jeff, please join us for a BBQ next Saturday at 6pm.
# Viet, please join us for a BBQ next Saturday at 6pm.
# Rui, please join us for a BBQ next Saturday at 6pm.
# Samantha, please join us for a BBQ next Saturday at 6pm.

# %%
guestlist = ["Yong-Mi","Jeff","Viet","Rui","Samantha"]
guestlist.insert(0, "Jason")
guestlist.insert(3, "Shawna")
guestlist.append("Miguel")
for guest in guestlist:
  print(guest + ", please join us for a BBQ next Saturday at 6pm.")
# Out:
# Jason, please join us for a BBQ next Saturday at 6pm.
# Yong-Mi, please join us for a BBQ next Saturday at 6pm.
# Jeff, please join us for a BBQ next Saturday at 6pm.
# Shawna, please join us for a BBQ next Saturday at 6pm.
# Viet, please join us for a BBQ next Saturday at 6pm.
# Rui, please join us for a BBQ next Saturday at 6pm.
# Samantha, please join us for a BBQ next Saturday at 6pm.
# Miguel, please join us for a BBQ next Saturday at 6pm.

# %%
RSVP = ["Yong-Mi","Jeff","Viet","Rui"]
RSVP [0] = "Samantha"
print(RSVP)
# Out:
# ['Samantha', 'Jeff', 'Viet', 'Rui']

# %% [markdown]
# The code still runs sucessfully but not with the results that we want. The second line modifies the list by overriding the first (0th) value. I could do RSVP.append("Samantha") to insert her to the end or RSVP.insert(0,"Samantha") to insert her to the beginning of the list.
